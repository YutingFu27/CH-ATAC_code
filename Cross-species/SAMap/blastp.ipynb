# %%
#blasp (macaca with other species)

# %%
##ma to mo

# %%
file1 = './pep/macaca_mouse/macaca.fa'
type1 = 'prot' #or 'prot' if file1 is a proteome
id1 = 'ma' #2-character ID (e.g. 'hu' for human)

file2 = './pep/macaca_mouse/Mouse.fa'
type2 = 'prot'
id2 = 'mo' #2-character ID (e.g. 'mo' for mouse)
# !bash /media/ggj/FYT/tools/SAMap-main/map_genes.sh --tr1 {file1} --t1 {type1} --n1 {id1} --tr2 {file2} --t2 {type2} --n2 {id2}
# Out:
# Building a new DB, current time: 02/17/2023 15:50:05
# New DB name:   /media/ggj/FYT/CH/CH-cross/Fig3/SAMap/pep/macaca_mouse/macaca.fa
# New DB title:  ./pep/macaca_mouse/macaca.fa
# Sequence type: Protein
# Keep MBits: T
# Maximum file size: 1000000000B
# FASTA-Reader: Ignoring invalid residues at position(s): On line 3125: 47
# FASTA-Reader: Ignoring invalid residues at position(s): On line 13379: 62
# FASTA-Reader: Ignoring invalid residues at position(s): On line 13386: 30
# FASTA-Reader: Ignoring invalid residues at position(s): On line 84823: 64
# FASTA-Reader: Ignoring invalid residues at position(s): On line 93713: 38
# FASTA-Reader: Ignoring invalid residues at position(s): On line 111890: 18
# FASTA-Reader: Ignoring invalid residues at position(s): On line 132804: 44
# FASTA-Reader: Ignoring invalid residues at position(s): On line 142811: 40
# FASTA-Reader: Ignoring invalid residues at position(s): On line 145991: 35
# ...

# %%
##ma to ze

# %%
file1 = './pep/macaca_zebrafish/ebrafish/ebrafish/macaca.fa'
type1 = 'prot' #or 'prot' if file1 is a proteome
id1 = 'ma' #2-character ID (e.g. 'hu' for human)

file2 = './pep/macaca_zebrafish/Zebrafish_1.fa'
type2 = 'prot'
id2 = 'ze' #2-character ID (e.g. 'mo' for mouse)
# !bash /media/ggj/FYT/tools/SAMap-main/map_genes.sh --tr1 {file1} --t1 {type1} --n1 {id1} --tr2 {file2} --t2 {type2} --n2 {id2}
# Out:
# Building a new DB, current time: 02/17/2023 19:51:48
# New DB name:   /media/ggj/FYT/CH/CH-cross/Fig3/SAMap/pep/macaca_zebrafish/macaca.fa
# New DB title:  ./pep/macaca_zebrafish/macaca.fa
# Sequence type: Protein
# Keep MBits: T
# Maximum file size: 1000000000B
# FASTA-Reader: Ignoring invalid residues at position(s): On line 3125: 47
# FASTA-Reader: Ignoring invalid residues at position(s): On line 13379: 62
# FASTA-Reader: Ignoring invalid residues at position(s): On line 13386: 30
# FASTA-Reader: Ignoring invalid residues at position(s): On line 84823: 64
# FASTA-Reader: Ignoring invalid residues at position(s): On line 93713: 38
# FASTA-Reader: Ignoring invalid residues at position(s): On line 111890: 18
# FASTA-Reader: Ignoring invalid residues at position(s): On line 132804: 44
# FASTA-Reader: Ignoring invalid residues at position(s): On line 142811: 40
# FASTA-Reader: Ignoring invalid residues at position(s): On line 145991: 35
# ...

# %%
#ma to dm

# %%
file1 = './pep/macaca_dmel/macaca.fa'
type1 = 'prot' #or 'prot' if file1 is a proteome
id1 = 'ma' #2-character ID (e.g. 'hu' for human)

file2 = './pep/macaca_dmel/Drosophila.fa'
type2 = 'prot'
id2 = 'dm' #2-character ID (e.g. 'mo' for mouse)
# !bash /media/ggj/FYT/tools/SAMap-main/map_genes.sh --tr1 {file1} --t1 {type1} --n1 {id1} --tr2 {file2} --t2 {type2} --n2 {id2}
# Out:
# Building a new DB, current time: 02/17/2023 23:35:49
# New DB name:   /media/ggj/FYT/CH/CH-cross/Fig3/SAMap/pep/macaca_dmel/macaca.fa
# New DB title:  ./pep/macaca_dmel/macaca.fa
# Sequence type: Protein
# Keep MBits: T
# Maximum file size: 1000000000B
# FASTA-Reader: Ignoring invalid residues at position(s): On line 3125: 47
# FASTA-Reader: Ignoring invalid residues at position(s): On line 13379: 62
# FASTA-Reader: Ignoring invalid residues at position(s): On line 13386: 30
# FASTA-Reader: Ignoring invalid residues at position(s): On line 84823: 64
# FASTA-Reader: Ignoring invalid residues at position(s): On line 93713: 38
# FASTA-Reader: Ignoring invalid residues at position(s): On line 111890: 18
# FASTA-Reader: Ignoring invalid residues at position(s): On line 132804: 44
# FASTA-Reader: Ignoring invalid residues at position(s): On line 142811: 40
# FASTA-Reader: Ignoring invalid residues at position(s): On line 145991: 35
# ...

# %%
#ma to ea

# %%
file1 = './pep/macaca_earthworm/macaca.fa'
type1 = 'prot' #or 'prot' if file1 is a proteome
id1 = 'ma' #2-character ID (e.g. 'hu' for human)

file2 = './pep/macaca_earthworm/EarthWorm.fa'
type2 = 'prot'
id2 = 'ea' #2-character ID (e.g. 'mo' for mouse)
# !bash /media/ggj/FYT/tools/SAMap-main/map_genes.sh --tr1 {file1} --t1 {type1} --n1 {id1} --tr2 {file2} --t2 {type2} --n2 {id2}
# Out:
# Building a new DB, current time: 02/19/2023 14:46:39
# New DB name:   /media/ggj/FYT/CH/CH-cross/Fig3/SAMap/pep/macaca_earthworm/EarthWorm.fa
# New DB title:  ./pep/macaca_earthworm/EarthWorm.fa
# Sequence type: Protein
# Keep MBits: T
# Maximum file size: 1000000000B
# Adding sequences from FASTA; added 26350 sequences in 0.670477 seconds.
# Running blastp in both directions
# FASTA-Reader: Ignoring invalid residues at position(s): On line 3125: 47
# FASTA-Reader: Ignoring invalid residues at position(s): On line 13379: 62
# FASTA-Reader: Ignoring invalid residues at position(s): On line 13386: 30
# FASTA-Reader: Ignoring invalid residues at position(s): On line 84823: 64
# FASTA-Reader: Ignoring invalid residues at position(s): On line 93713: 38
# FASTA-Reader: Ignoring invalid residues at position(s): On line 111890: 18
# FASTA-Reader: Ignoring invalid residues at position(s): On line 132804: 44
# FASTA-Reader: Ignoring invalid residues at position(s): On line 142811: 40
# ...
